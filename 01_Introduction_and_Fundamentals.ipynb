# %% [markdown]
# # 📚 Notebook 01: Introduction and Fundamentals
#
# **LangChain 1.0.5+ | Mixed Level Class**
#
# ---
#
# ## 🎯 Learning Objectives
#
# By the end of this notebook, you will understand:
# 1. What LangChain is and why it's useful
# 2. LangChain's modular architecture
# 3. Core concepts: Documents, Chains, and LCEL
# 4. How to set up your development environment
# 5. The difference between LangChain and traditional ML pipelines
#
# ---
#
# ## 📖 Table of Contents
#
# 1. [What is LangChain?](#what-is-langchain)
# 2. [LangChain Architecture](#architecture)
# 3. [Environment Setup](#setup)
# 4. [Core Concepts](#core-concepts)
# 5. [Quick Start Example](#quick-start)
# 6. [LangChain vs Traditional Pipelines](#comparison)
# 7. [Summary & Next Steps](#summary)
#
# ---

# %% [markdown]
# <a id="what-is-langchain"></a>
# ## 1. What is LangChain? 🤔
#
# ### 🔰 BEGINNER SECTION
#
# **LangChain** is an open-source framework that makes it easy to build applications powered by Large Language Models (LLMs) like GPT-4, Claude, or Llama.
#
# ### Why LangChain?
#
# Imagine you want to build a chatbot that can:
# - Answer questions about your company's PDF documents
# - Search through your database
# - Remember previous conversations
# - Call external APIs
#
# Without LangChain, you'd need to:
# 1. ✍️ Write code to load and parse PDFs
# 2. ✍️ Convert text to embeddings
# 3. ✍️ Store embeddings in a vector database
# 4. ✍️ Implement semantic search
# 5. ✍️ Format prompts for the LLM
# 6. ✍️ Handle LLM API calls
# 7. ✍️ Manage conversation memory
#
# **With LangChain:**
# - ✅ All these components are pre-built and ready to use
# - ✅ You just connect them like LEGO blocks
# - ✅ Focus on your application logic, not infrastructure
#
# ### 🎓 INTERMEDIATE NOTE
#
# LangChain provides:
# - **Abstractions**: Unified interfaces for different LLMs, vector stores, and tools
# - **Chains**: Composable workflows using LCEL (LangChain Expression Language)
# - **Agents**: Autonomous systems that can use tools and make decisions
# - **Memory**: Conversation history and context management
# - **Callbacks**: Monitoring, logging, and debugging hooks

# %% [markdown]
# <a id="architecture"></a>
# ## 2. LangChain Architecture 🏗️
#
# ### 🔰 BEGINNER: Visual Architecture
#
# ```
# ┌─────────────────────────────────────────────────────────┐
# │                    YOUR APPLICATION                     │
# └─────────────────────────────────────────────────────────┘
#                            ↓
# ┌─────────────────────────────────────────────────────────┐
# │                  LANGCHAIN FRAMEWORK                    │
# │  ┌──────────┐  ┌──────────┐  ┌──────────┐  ┌─────────┐  │
# │  │ Document │  │   Text   │  │ Embeddings│  │ Vector  │ │
# │  │ Loaders  │→ │ Splitters│→ │  Models   │→ │ Stores  │ │
# │  └──────────┘  └──────────┘  └──────────┘  └─────────┘│
# │                                                         │
# │  ┌──────────┐  ┌──────────┐  ┌──────────┐               │
# │  │Retrievers│  │ Prompts  │  │   LLMs   │               │
# │  └──────────┘  └──────────┘  └──────────┘               │
# │                                                         │
# │  ┌──────────────────────────────────────────────────┐   │
# │  │         LCEL (LangChain Expression Language)     │   │
# │  │         Connects everything with | operator      │   │
# │  └──────────────────────────────────────────────────┘   │
# └─────────────────────────────────────────────────────────┘
#                            ↓
# ┌─────────────────────────────────────────────────────────┐
# │             EXTERNAL SERVICES & DATA                    │
# │  • NVIDIA NIM / LLM APIs  • Vector Databases            │
# │  • PDF Files              • Websites                    │
# │  • Databases              • APIs                        │
# └─────────────────────────────────────────────────────────┘
# ```
#
# ### 🎓 INTERMEDIATE: Package Structure (LangChain 1.0+)
#
# LangChain is organized into several packages:
#
# | Package | Purpose | Example Imports |
# |---------|---------|------------------|
# | **langchain-core** | Core abstractions, base classes | `from langchain_core.documents import Document` |
# | **langchain-community** | Community integrations (loaders, vector stores) | `from langchain_community.document_loaders import PyPDFLoader` |
# | **langchain-nvidia-ai-endpoints** | NVIDIA NIM integrations | `from langchain_nvidia_ai_endpoints import ChatNVIDIA, NVIDIAEmbeddings` |
# | **langchain-text-splitters** | Text splitting utilities | `from langchain_text_splitters import RecursiveCharacterTextSplitter` |
#
# **Why this matters:** In LangChain 1.0+, you import from specific packages instead of `langchain` directly. This reduces dependencies and improves modularity.

# %% [markdown]
# <a id="setup"></a>
# ## 3. Environment Setup 🛠️
#
# ### 🔰 BEGINNER: Step-by-Step Setup
#
# Let's verify your environment is ready!

# %%
# Step 1: Check Python version (should be 3.9+)
import sys
print(f"Python version: {sys.version}")

# Check if Python is 3.9 or higher
if sys.version_info >= (3, 9):
    print("✅ Python version is compatible")
else:
    print("❌ Please upgrade to Python 3.9 or higher")
# Out:
# Python version: 3.12.7 | packaged by Anaconda, Inc. | (main, Oct  4 2024, 08:22:19) [Clang 14.0.6 ]
# ✅ Python version is compatible

# %%
# Step 2: Import LangChain and check version
import langchain
from langchain_core import __version__ as core_version

print(f"LangChain version: {langchain.__version__}")
print(f"LangChain Core version: {core_version}")

# We're using LangChain 1.0.5+ for this course
if langchain.__version__ >= "1.0":
    print("✅ LangChain 1.0+ detected")
else:
    print("❌ Please upgrade: pip install --upgrade langchain")
# Out:
# LangChain version: 1.2.18
# LangChain Core version: 1.3.3
# ✅ LangChain 1.0+ detected

# %%
# Step 3: Load environment variables (API keys)
from dotenv import load_dotenv
import os

# Load .env file
load_dotenv()

# Check if NVIDIA API key is set
# NOTE: We don't print the actual key for security!
if os.getenv("NVIDIA_API_KEY"):
    print("✅ NVIDIA_API_KEY found")
else:
    print("❌ NVIDIA_API_KEY not found")
    print("   Create a .env file with: NVIDIA_API_KEY=nvapi-your-key-here")

# Check for Google API key (optional, for Google Gemini)
if os.getenv("GOOGLE_API_KEY"):
    print("✅ GOOGLE_API_KEY found")
else:
    print("⚠️  GOOGLE_API_KEY not found (optional for this notebook)")
# Out:
# ✅ NVIDIA_API_KEY found
# ⚠️  GOOGLE_API_KEY not found (optional for this notebook)

# %% [markdown]
# ### 📝 Setting Up Your .env File
#
# If you don't have a `.env` file, create one in the project root:
#
# ```bash
# # .env file
# NVIDIA_API_KEY=nvapi-your-key-here
# GOOGLE_API_KEY=your-google-key-here
# ```
#
# **⚠️ SECURITY WARNING:**
# - Never commit `.env` files to Git
# - Add `.env` to your `.gitignore` file
# - Never hardcode API keys in your code

# %% [markdown]
# <a id="core-concepts"></a>
# ## 4. Core Concepts 📚
#
# ### 4.1 Documents 📄
#
# ### 🔰 BEGINNER
#
# A **Document** is LangChain's way of representing a piece of text with metadata.
#
# Think of it like a note card:
# - **Front (page_content):** The actual text
# - **Back (metadata):** Information about the text (source, page number, date, etc.)

# %%
# Creating a Document manually
from langchain_core.documents import Document

# Create a simple document
doc = Document(
    page_content="LangChain makes building LLM applications easy!",
    metadata={
        "source": "introduction.txt",
        "author": "LangChain Team",
        "date": "2025-01-15"
    }
)

# Access the content
print("Content:")
print(doc.page_content)
print("\nMetadata:")
print(doc.metadata)
print(f"\nSource: {doc.metadata['source']}")
# Out:
# Content:
# LangChain makes building LLM applications easy!
#
# Metadata:
# {'source': 'introduction.txt', 'author': 'LangChain Team', 'date': '2025-01-15'}
#
# Source: introduction.txt

# %% [markdown]
# ### 🎓 INTERMEDIATE: Why Metadata Matters
#
# Metadata is crucial for:
# 1. **Citation**: Showing users where information came from
# 2. **Filtering**: Only search documents from specific sources
# 3. **Debugging**: Tracking which documents are being retrieved
# 4. **Analytics**: Understanding which sources are most useful

# %%
# Creating multiple documents (like a mini knowledge base)
documents = [
    Document(
        page_content="Python is a high-level programming language.",
        metadata={"category": "programming", "difficulty": "beginner"}
    ),
    Document(
        page_content="Machine learning is a subset of artificial intelligence.",
        metadata={"category": "AI", "difficulty": "intermediate"}
    ),
    Document(
        page_content="RAG combines retrieval and generation for better LLM outputs.",
        metadata={"category": "AI", "difficulty": "advanced"}
    )
]

# Print all documents
for i, doc in enumerate(documents, 1):
    print(f"\n📄 Document {i}:")
    print(f"   Content: {doc.page_content}")
    print(f"   Category: {doc.metadata['category']}")
    print(f"   Difficulty: {doc.metadata['difficulty']}")
# Out:
# 📄 Document 1:
#    Content: Python is a high-level programming language.
#    Category: programming
#    Difficulty: beginner
#
# 📄 Document 2:
#    Content: Machine learning is a subset of artificial intelligence.
#    Category: AI
#    Difficulty: intermediate
#
# 📄 Document 3:
#    Content: RAG combines retrieval and generation for better LLM outputs.
#    Category: AI
#    Difficulty: advanced

# %% [markdown]
# ### 4.2 LCEL (LangChain Expression Language) 🔗
#
# ### 🔰 BEGINNER
#
# **LCEL** is a way to connect different components using the pipe operator `|`.
#
# Think of it like a factory assembly line:
# ```
# Input → Component 1 → Component 2 → Component 3 → Output
# ```
#
# ### Before LCEL (Old Way - Messy!):
# ```python
# output = component3(component2(component1(input)))
# ```
#
# ### With LCEL (New Way - Clean!):
# ```python
# chain = component1 | component2 | component3
# output = chain.invoke(input)
# ```

# %% [markdown]
# ### 🎓 INTERMEDIATE: LCEL Deep Dive
#
# LCEL provides:
# - **Streaming**: Stream outputs as they're generated
# - **Batch Processing**: Process multiple inputs efficiently
# - **Async Support**: Non-blocking operations
# - **Debugging**: Better error messages and logging
# - **Type Safety**: Better IDE autocomplete
#
# **Key Methods:**
# - `.invoke(input)`: Process single input
# - `.batch([input1, input2])`: Process multiple inputs
# - `.stream(input)`: Stream output tokens
# - `.ainvoke(input)`: Async version of invoke

# %%
# Simple LCEL Example: String Transformation Chain
from langchain_core.runnables import RunnableLambda

# Create simple transformation functions
def uppercase(text: str) -> str:
    """Convert text to uppercase"""
    print(f"  Step 1: uppercase → {text.upper()}")
    return text.upper()

def add_prefix(text: str) -> str:
    """Add a prefix to text"""
    result = f"RESULT: {text}"
    print(f"  Step 2: add_prefix → {result}")
    return result

def add_emoji(text: str) -> str:
    """Add emoji to text"""
    result = f"✅ {text}"
    print(f"  Step 3: add_emoji → {result}")
    return result

# Create runnables (components that can be chained)
uppercase_runnable = RunnableLambda(uppercase)
prefix_runnable = RunnableLambda(add_prefix)
emoji_runnable = RunnableLambda(add_emoji)

# Build the chain using LCEL
chain = uppercase_runnable | prefix_runnable | emoji_runnable

# Execute the chain
print("Input: 'hello langchain'")
print("\nProcessing:")
result = chain.invoke("hello langchain")
print(f"\nFinal Output: {result}")
# Out:
# Input: 'hello langchain'
#
# Processing:
#   Step 1: uppercase → HELLO LANGCHAIN
#   Step 2: add_prefix → RESULT: HELLO LANGCHAIN
#   Step 3: add_emoji → ✅ RESULT: HELLO LANGCHAIN
#
# Final Output: ✅ RESULT: HELLO LANGCHAIN

# %% [markdown]
# ### 4.3 Chains 🔗
#
# ### 🔰 BEGINNER
#
# A **Chain** is a sequence of operations. Common chain types:
#
# 1. **Simple Chain**: Input → Process → Output
# 2. **RAG Chain**: Query → Retrieve → Generate → Answer
# 3. **Multi-step Chain**: Input → Step 1 → Step 2 → Step 3 → Output
#
# We'll build complex chains in later notebooks!

# %% [markdown]
# <a id="quick-start"></a>
# ## 5. Quick Start Example 🚀
#
# ### 🔰 BEGINNER: Your First LLM Call
#
# Let's make our first call to an LLM using LangChain!

# %%
# Import ChatNVIDIA (the LLM interface)
from langchain_nvidia_ai_endpoints import ChatNVIDIA

# Initialize the LLM
# model: Which GPT model to use
# temperature: 0 = deterministic, 1 = creative
llm = ChatNVIDIA(
    model="meta/llama-3.3-70b-instruct",  # Cheaper, faster model for learning
    temperature=0  # Deterministic outputs for learning
)

# Make a simple call
response = llm.invoke("What is LangChain in two sentences?")

# Print the response
print("Question: What is LangChain in one sentence?")
print(f"\nAnswer: {response.content}")
# Out:
# Question: What is LangChain in one sentence?
#
# Answer: LangChain is an open-source framework designed to help developers build applications that utilize large language models (LLMs) more efficiently and effectively. It provides a set of tools and libraries that simplify the process of integrating LLMs into various projects, allowing developers to focus on building innovative applications rather than worrying about the underlying infrastructure.

# %% [markdown]
# ### FOR GEMINI

# %%
#!uv pip install -U langchain-nvidia-ai-endpoints

# %%
from langchain_nvidia_ai_endpoints import ChatNVIDIA

# %%
llm = ChatNVIDIA(
model="meta/llama-3.3-70b-instruct",  # NVIDIA NIM model
temperature=0  # Deterministic outputs for learning
)

# Make a simple call
response = llm.invoke("What is LangChain in one sentence?")

# Print the response
print("Question: What is LangChain in one sentence?")
print(f"\nAnswer: {response.content}")
# Out:
# Question: What is LangChain in one sentence?
#
# Answer: LangChain is an open-source framework that enables developers to build applications powered by large language models, providing a set of tools and libraries to interact with and integrate these models into various projects.

# %%
# langchain-nvidia-ai-endpoints already installed
# !uv pip install langchain-nvidia-ai-endpoints

# %%
from langchain_nvidia_ai_endpoints import ChatNVIDIA

llm = ChatNVIDIA(
model="meta/llama-3.3-70b-instruct",  # NVIDIA NIM model
temperature=0  # Deterministic outputs for learning
)

# Make a simple call
response = llm.invoke("What is LangChain in one sentence?")

# Print the response
print("Question: What is LangChain in one sentence?")
print(f"\nAnswer: {response.content}")
# Out:
# Question: What is LangChain in one sentence?
#
# Answer: LangChain is an open-source framework that enables developers to build applications powered by large language models, providing a set of tools and libraries to simplify the process of integrating AI models into their projects.

# %% [markdown]
# ### 🎓 INTERMEDIATE: Understanding the Response Object

# %%
# The response is an AIMessage object with metadata
print("Response Type:", type(response))
print("\nContent:", response.content)
print("\nResponse Metadata:")
print(response.response_metadata)

# Access specific metadata
if 'token_usage' in response.response_metadata:
    usage = response.response_metadata['token_usage']
    print(f"\nTokens Used:")
    print(f"  Prompt: {usage.get('prompt_tokens', 'N/A')}")
    print(f"  Completion: {usage.get('completion_tokens', 'N/A')}")
    print(f"  Total: {usage.get('total_tokens', 'N/A')}")
# Out:
# Response Type: <class 'langchain_core.messages.ai.AIMessage'>
#
# Content: LangChain is an open-source framework that enables developers to build applications powered by large language models, providing a set of tools and libraries to simplify the process of integrating AI models into their projects.
#
# Response Metadata:
# {'role': 'assistant', 'content': 'LangChain is an open-source framework that enables developers to build applications powered by large language models, providing a set of tools and libraries to simplify the process of integrating AI models into their projects.', 'refusal': None, 'annotations': None, 'audio': None, 'function_call': None, 'tool_calls': [], 'reasoning': None, 'reasoning_content': None, 'token_usage': {'prompt_tokens': 43, 'total_tokens': 82, 'completion_tokens': 39, 'prompt_tokens_details': None}, 'finish_reason': 'stop', 'model_name': 'meta/llama-3.3-70b-instruct'}
#
# Tokens Used:
#   Prompt: 43
#   Completion: 39
#   Total: 82

# %% [markdown]
# ### 🔰 BEGINNER: Using Prompts
#
# Instead of plain strings, use **prompt templates** for better control:

# %%
from langchain_core.prompts import ChatPromptTemplate


# Create a prompt template
# {topic} is a variable we'll fill in later
prompt = ChatPromptTemplate.from_template(
    "Explain {topic} in simple terms suitable for beginners."
)

# View the prompt structure
print("Prompt Template:")
print(prompt.messages[0].prompt.template)
# Out:
# Prompt Template:
# Explain {topic} in simple terms suitable for beginners.

# %%
# Build a chain: Prompt → LLM
from langchain_core.output_parsers import StrOutputParser

# Components:
# 1. prompt: Formats the input
# 2. llm: Generates the response
# 3. StrOutputParser: Extracts just the text from the response

chain = prompt | llm | StrOutputParser()

# Use the chain with different topics
topics = ["machine learning", "embeddings", "vector databases"]

for topic in topics:
    print(f"\n{'='*60}")
    print(f"Topic: {topic.upper()}")
    print('='*60)
    
    # Invoke the chain
    explanation = chain.invoke({"topic": topic})
    print(explanation)
# Out:
# ============================================================
# Topic: MACHINE LEARNING
# ============================================================
# **What is Machine Learning?**
#
# Machine learning is a type of artificial intelligence (AI) that allows computers to learn and improve from data without being explicitly programmed. It's like teaching a child to recognize objects, but instead of using words, you show them many examples of the object, and they learn to identify it on their own.
#
# **How Does it Work?**
#
# Imagine you want to teach a computer to recognize pictures of cats and dogs. Here's a simplified step-by-step process:
#
# 1. **Data Collection**: You gather a large number of pictures of cats and dogs, along with labels (e.g., "cat" or "dog").
# 2. **Training**: You feed this data into a machine learning algorithm, which analyzes the pictures and looks for patterns.
# 3. **Pattern Recognition**: The algorithm identifies features that distinguish cats from dogs, such as ear shape, whiskers, or fur texture.
# 4. **Model Building**: The algorithm creates a model that can predict whether a new, unseen picture is a cat or a dog.
# 5. **Testing**: You test the model with new pictures to see how well it performs.
#
# **Types of Machine Learning**
#
# There are three main types of machine learning:
#
# 1. **Supervised Learning**: The algorithm learns from labeled data, like the cat and dog example.
# 2. **Unsupervised Learning**: The algorithm finds patterns in unlabeled data, such as grouping similar customers based on their buying behavior.
# 3. **Reinforcement Learning**: The algorithm learns through trial and error, receiving rewards or penalties for its actions, like a game-playing AI.
#
# **Real-World Applications**
#
# Machine learning is used in many areas, including:
#
# * Image recognition (e.g., self-driving cars, facial recognition)
# * Natural Language Processing (e.g., chatbots, language translation)
# * Predictive maintenance (e.g., forecasting equipment failures)
# * Recommendation systems (e.g., personalized product suggestions)
#
# **In Summary**
#
# Machine learning is a powerful technology that enables computers to learn from data and improve their performance over time. By understanding the basics of machine learning, you can appreciate the many ways it's transforming industries and our daily lives.
#
# ============================================================
# Topic: EMBEDDINGS
# ============================================================
# **What are Embeddings?**
#
# Embeddings are a way to represent complex data, like words or images, as numbers in a computer. This allows machines to understand and work with the data more easily.
#
# **Think of it like a Map**
#
# Imagine you're trying to explain where a city is to someone. You could give them the exact latitude and longitude coordinates, but that's not very intuitive. Instead, you could show them a map, where the city is represented by a point on a 2D surface. This makes it easier to understand the city's relationship to other places.
#
# **How Embeddings Work**
#
# In the same way, embeddings take complex data, like words, and represent them as points in a high-dimensional space (think of it like a map with many dimensions). Each point in this space corresponds to a specific word or concept.
#
# For example, in a word embedding:
#
# * The word "dog" might be represented by a point close to the word "cat", because they're both animals.
# * The word "car" might be represented by a point far away from "dog" and "cat", because it's a vehicle.
#
# **Why are Embeddings Useful?**
#
# Embeddings are useful because they allow machines to:
#
# * Understand the relationships between different pieces of data
# * Make predictions or recommendations based on these relationships
# * Work with complex data in a more efficient and effective way
#
# **Common Types of Embeddings**
#
# Some common types of embeddings include:
#
# * Word embeddings (like Word2Vec or GloVe)
# * Image embeddings (like convolutional neural networks)
# * Graph embeddings (like node2vec or graphSAGE)
#
# **In Summary**
#
# Embeddings are a way to represent complex data as numbers in a computer, making it easier for machines to understand and work with the data. They're like a map that shows the relationships between different pieces of data, and are useful for a wide range of applications, from natural language processing to computer vision.
#
# ============================================================
# Topic: VECTOR DATABASES
# ============================================================
# **Introduction to Vector Databases**
# =====================================
#
# A vector database is a type of database that stores and manages data in the form of vectors, which are mathematical representations of objects or concepts. In simple terms, a vector is a list of numbers that describes a point in a high-dimensional space.
#
# **What are Vectors?**
# --------------------
#
# Imagine you're trying to describe a picture of a cat. You could use words like "cat," "animal," "furry," and "whiskers." But a computer can't understand these words in the same way that humans do. Instead, a computer can represent the picture of a cat as a vector, which is a list of numbers that describes the characteristics of the picture.
#
# For example, the vector might look like this:
#
# [0.8, 0.2, 0.1, 0.5, 0.3]
#
# Each number in the vector represents a different feature of the picture, such as the shape of the cat's ears, the color of its fur, or the length of its whiskers.
#
# **How do Vector Databases Work?**
# --------------------------------
#
# A vector database stores these vectors in a way that allows them to be searched and compared. When you query a vector database, you provide a vector that describes what you're looking for, and the database returns a list of vectors that are similar to the one you provided.
#
# For example, if you're searching for pictures of cats, you might provide a vector that describes the characteristics of a cat. The vector database would then return a list of vectors that describe pictures of cats, along with a score that indicates how similar each picture is to the one you're looking for.
#
# **Key Features of Vector Databases**
# ------------------------------------
#
# Here are some key features of vector databases:
#
# * **High-dimensional data**: Vector databases can handle high-dimensional data, which means they can store and manage large numbers of features or characteristics.
# * **Similarity search**: Vector databases allow you to search for similar vectors, which makes them useful for applications like image and video search, recommendation systems, and natural language processing.
# * **Scalability**: Vector databases are designed to handle large amounts of data and can scale to meet the needs of big data applications.
#
# **Use Cases for Vector Databases**
# ---------------------------------
#
# Vector databases have a wide range of use cases, including:
#
# * **Image and video search**: Vector databases can be used to search for images and videos that are similar to a given example.
# * **Recommendation systems**: Vector databases can be used to build recommendation systems that suggest products or services based on a user's preferences.
# * **Natural language processing**: Vector databases can be used to analyze and understand human language, which makes them useful for applications like chatbots and language translation.
#
# In summary, vector databases are a type of database that stores and manages data in the form of vectors, which are mathematical representations of objects or concepts. They're useful for applications like image and video search, recommendation systems, and natural language processing, and have a wide range of use cases in big data and AI.

# %% [markdown]
# ### 🎓 INTERMEDIATE: Batch Processing
#
# Process multiple inputs efficiently using `.batch()`:

# %%
# Batch process multiple topics at once
topics_batch = [
    {"topic": "RAG"},
    {"topic": "LCEL"},
    {"topic": "LangChain agents"}
]

# Batch processing is more efficient than calling invoke() multiple times
results = chain.batch(topics_batch)

# Print results
for i, (input_dict, result) in enumerate(zip(topics_batch, results), 1):
    print(f"\n{i}. {input_dict['topic'].upper()}:")
    print(f"   {result[:100]}...")  # Print first 100 chars
# Out:
# 1. RAG:
#    RAG (Red, Amber, Green) is a simple and widely used framework for evaluating and reporting the statu...
#
# 2. LCEL:
#    LCEL stands for Lowest Common Emission Level. However, I couldn't find any information on LCEL being...
#
# 3. LANGCHAIN AGENTS:
#    LangChain agents are a concept in artificial intelligence (AI) that can be a bit complex, but I'll b...

# %% [markdown]
# <a id="comparison"></a>
# ## 6. LangChain vs Traditional ML Pipelines 🆚
#
# ### 🔰 BEGINNER: Key Differences
#
# | Aspect | Traditional ML | LangChain |
# |--------|---------------|------------|
# | **Setup** | Complex, manual | Pre-built components |
# | **Integration** | Write custom code | Use existing integrations |
# | **Composability** | Difficult to chain | Easy with LCEL |
# | **Debugging** | Manual logging | Built-in callbacks |
# | **Prototyping** | Slow | Very fast |
# | **Code Reuse** | Limited | High |
#
# ### Example: Building a Q&A System
#
# #### Without LangChain (50+ lines):
# ```python
# # import openai  # Replaced by langchain_nvidia_ai_endpoints
# import PyPDF2
# import faiss
# import numpy as np
#
# # 1. Load PDF manually
# def load_pdf(file_path):
#     reader = PyPDF2.PdfReader(file_path)
#     text = ""
#     for page in reader.pages:
#         text += page.extract_text()
#     return text
#
# # 2. Split text manually
# def split_text(text, chunk_size=1000):
#     chunks = []
#     for i in range(0, len(text), chunk_size):
#         chunks.append(text[i:i+chunk_size])
#     return chunks
#
# # 3. Create embeddings manually
# def create_embeddings(chunks):
#     embeddings = []
#     for chunk in chunks:
#         response = # openai.Embedding.create  # Legacy API — use NVIDIAEmbeddings instead(
#             input=chunk,
#             model="nvidia/llama-3.2-nv-embedqa-1b-v2"
#         )
#         embeddings.append(response['data'][0]['embedding'])
#     return np.array(embeddings)
#
# # 4. Create vector store manually
# def create_vector_store(embeddings):
#     dimension = embeddings.shape[1]
#     index = faiss.IndexFlatL2(dimension)
#     index.add(embeddings)
#     return index
#
# # 5. Search manually
# def search(query, index, chunks):
#     query_embedding = # openai.Embedding.create  # Legacy API — use NVIDIAEmbeddings instead(
#         input=query,
#         model="nvidia/llama-3.2-nv-embedqa-1b-v2"
#     )['data'][0]['embedding']
#
#     distances, indices = index.search(
#         np.array([query_embedding]), k=3
#     )
#     return [chunks[i] for i in indices[0]]
#
# # 6. Generate answer manually
# def generate_answer(query, context):
#     prompt = f"Context: {context}\n\nQuestion: {query}\n\nAnswer:"
#     response = # openai.ChatCompletion.create  # Legacy API — use ChatNVIDIA instead(
#         model="meta/llama-3.1-8b-instruct",
#         messages=[{"role": "user", "content": prompt}]
#     )
#     return response['choices'][0]['message']['content']
#
# # Use it:
# text = load_pdf("document.pdf")
# chunks = split_text(text)
# embeddings = create_embeddings(chunks)
# index = create_vector_store(embeddings)
# relevant_chunks = search("What is RAG?", index, chunks)
# answer = generate_answer("What is RAG?", " ".join(relevant_chunks))
# ```
#
# #### With LangChain (10 lines!):
# ```python
# from langchain_community.document_loaders import PyPDFLoader
# from langchain_text_splitters import RecursiveCharacterTextSplitter
# from langchain_nvidia_ai_endpoints import NVIDIAEmbeddings, ChatNVIDIA
# from langchain_community.vectorstores import FAISS
# from langchain_core.prompts import ChatPromptTemplate
# from langchain_core.output_parsers import StrOutputParser
# from langchain_core.runnables import RunnablePassthrough
#
# # Load, split, embed, and store
# docs = PyPDFLoader("document.pdf").load()
# chunks = RecursiveCharacterTextSplitter(chunk_size=1000).split_documents(docs)
# vectorstore = FAISS.from_documents(chunks, NVIDIAEmbeddings())
# retriever = vectorstore.as_retriever()
#
# # Build RAG chain
# prompt = ChatPromptTemplate.from_template(
#     "Context: {context}\n\nQuestion: {question}\n\nAnswer:"
# )
# chain = (
#     {"context": retriever, "question": RunnablePassthrough()}
#     | prompt | ChatNVIDIA() | StrOutputParser()
# )
#
# # Use it:
# answer = chain.invoke("What is RAG?")
# ```
#
# **50+ lines → 10 lines!** 🎉

# %% [markdown]
# <a id="summary"></a>
# ## 7. Summary & Next Steps 📝
#
# ### 🎉 What You Learned
#
# ✅ **LangChain** is a framework that simplifies building LLM applications
#
# ✅ **Architecture** is modular: loaders, splitters, embeddings, vector stores, chains
#
# ✅ **Documents** contain `page_content` (text) and `metadata` (information about the text)
#
# ✅ **LCEL** uses the `|` operator to chain components together
#
# ✅ **Chains** connect multiple components to create complex workflows
#
# ✅ LangChain **dramatically reduces code** compared to manual implementations
#
# ### 🔰 For Beginners
# You now understand:
# - What LangChain is and why it's useful
# - How to set up your environment
# - Basic concepts: Documents and Chains
# - How to make your first LLM call
#
# ### 🎓 For Intermediate Learners
# You now understand:
# - LangChain's package structure (1.0+ reorganization)
# - LCEL internals and advantages
# - Metadata usage for filtering and citation
# - Batch processing for efficiency
#
# ### 📚 Next Notebooks
#
# 1. **Notebook 02**: Document Loaders (PDF, CSV, JSON, HTML)
# 2. **Notebook 03**: Text Splitting Strategies
# 3. **Notebook 04**: Embeddings and Vector Representations
# 4. **Notebook 05**: Vector Stores (FAISS, Chroma)
# 5. **Notebook 06**: Retrieval Strategies
# 6. **Notebook 07**: Complete RAG Pipeline
#
# ### 💡 Practice Exercises
#
# Before moving to the next notebook, try these:
#
# 1. **Easy**: Create 5 Documents about different topics with meaningful metadata
# 2. **Medium**: Build a chain that takes a topic and generates a haiku about it
# 3. **Advanced**: Create a chain that summarizes text in different styles (formal, casual, technical)
#
# ---
#
# ## 🎓 Additional Resources
#
# - [Official LangChain Documentation](https://python.langchain.com/docs/)
# - [LCEL Guide](https://python.langchain.com/docs/expression_language/)
# - [LangChain GitHub](https://github.com/langchain-ai/langchain)
#
# ---
#
# **Ready for more? Continue to Notebook 02: Document Loaders! 🚀**
